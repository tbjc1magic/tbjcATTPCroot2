# %%
import pylab as plt
import cv2
import numpy as np 
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas

# %matplotlib inline
img = cv2.imread('xwd-f211-animals.jpg')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray,100,200,apertureSize = 3)
lines = cv2.HoughLines(gray,100,np.pi/360,1000)

print lines[0].shape
lines = cv2.HoughLines(edges,1,np.pi/180,100)

for x in range(0, len(lines)):
    #print lines[x].shape
    for rho,theta in lines[x]:
        #cv2.line(img,(x1,y1),(x2,y2),(0,255,0),2)
        a = np.cos(theta)
        b = np.sin(theta)
        x0 = a*rho
        y0 = b*rho
        x1 = int(x0 + 1000*(-b))
        y1 = int(y0 + 1000*(a))
        x2 = int(x0 - 1000*(-b))
        y2 = int(y0 - 1000*(a))

        cv2.line(img,(x1,y1),(x2,y2),(0,0,255),2)
    
plt.imshow(img)
# Out:
# (1, 2)

# %%
nn =  np.zeros([500,500])

for x in range(10,400):
    
    nn[x][x] = 255 
    
plt.imshow(nn)

# %%
fig = plt.gcf()
canvas = FigureCanvas(fig)
fig.gca().axis('off')
ax=fig.gca()

ax.plot((0,1),(0,1))
ax.plot((0,1),(1,0))
ax.plot((0,1),(0.5,0.5))

canvas.draw()       # draw the canvas, cache the renderer


width, height = fig.get_size_inches() * fig.get_dpi()
image = np.fromstring(canvas.tostring_rgb(), dtype='uint8')
image = image.reshape(int(height), int(width), 3);
plt.gcf()
#plt.imshow(image)


plt.figure()

gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray,5,10,apertureSize = 3)
#lines = cv2.HoughLines(gray,100,np.pi/360,1000)

#print np.min(gray),np.min(edges)


lines = cv2.HoughLines(nn.astype(np.uint8),1,np.pi/1800,300)
print lines.shape
for x in range(0, lines.shape[0]):
    #print lines[x].shape
    for rho,theta in lines[x]:
        #cv2.line(img,(x1,y1),(x2,y2),(0,255,0),2)
        a = np.cos(theta)
        b = np.sin(theta)
        x0 = a*rho
        y0 = b*rho
        x1 = int(x0 + 1000*(-b))
        y1 = int(y0 + 1000*(a))
        x2 = int(x0 - 1000*(-b))
        y2 = int(y0 - 1000*(a))

        plt.plot((x1,x2),(y1,y2))
        #cv2.line(image,(x1,y1),(x2,y2),(0,0,255),2)
    
plt.imshow(nn)
# Out:
# (1, 1, 2)

# %%
fig = plt.gcf()
canvas = FigureCanvas(fig)
fig.gca().axis('off')
ax=fig.gca()

ax.plot((0,1),(0,1))
ax.plot((0,1),(1,0))
ax.plot((0,1),(0.5,0.5))

canvas.draw()       # draw the canvas, cache the renderer


width, height = fig.get_size_inches() * fig.get_dpi()
image = np.fromstring(canvas.tostring_rgb(), dtype='uint8')
image = image.reshape(int(height), int(width), 3);
plt.gcf()
#plt.imshow(image)


plt.figure()

gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray,5,10,apertureSize = 3)
#lines = cv2.HoughLines(gray,100,np.pi/360,1000)

#print np.min(gray),np.min(edges)


lines = cv2.HoughLinesP(255-gray,1,np.pi/1800,100)
print lines.shape
for x in range(0, len(lines)):
    for x1,y1,x2,y2 in lines[x]:
        cv2.line(image,(x1,y1),(x2,y2),(0,255,0),10)
    
plt.imshow(image)
# Out:
# (34, 1, 4)
