# %%
from sqlalchemy import *
import numpy as np
import pylab as plt
import pandas as pd
from peakdetect import peakdetect
from scipy.ndimage.interpolation import shift
from matplotlib.colors import LogNorm

# %matplotlib inline

# %%
engine = create_engine('sqlite+pysqlite:///../SQL/72_8.db')

# %%
import time
start_time = time.time()
ADCdf = pd.io.sql.read_sql("SELECT * FROM ADC", engine)
Hitdf = pd.io.sql.read_sql("SELECT * FROM Hit", engine)
PSAdf = pd.io.sql.read_sql("SELECT * FROM PSA", engine)
ProtoMapdf = pd.io.sql.read_sql("SELECT * FROM ProtoMap", engine)
#RawADCdf = pd.io.sql.read_sql("SELECT * FROM RawADC", engine)
end_time = time.time()
print end_time-start_time
# Out:
# 158.154514074

# %%
def Process(Event):
    mesh = Event.iloc[:,3:][Event.iloc[:,3:]>20].sum(axis=0)
    #print mesh
    return mesh
start_time = time.time()
mesh_df = ADCdf.groupby('EventID').apply(Process)
end_time = time.time()
print end_time-start_time
# Out:
# 9.22590303421

# %%
def convolve(event):
    mesh_convol = np.convolve(event.values,([1]*10)[::-1],'same')
    return pd.Series(mesh_convol,index=['t'+str(i) for i in range(512)])
convol_df=mesh_df.apply(convolve,axis=1)
convol_df.reset_index(inplace=True)

# %%
status_df = pd.read_csv("72_8_t0.csv")
status_df.columns = ['EventID','trigger']

# %%
grad = np.gradient(convol_df.iloc[0].values)
mx = np.argmax(grad)
my = grad[mx]
plt.plot(convol_df.iloc[0].values*0.1)
plt.plot(grad)
plt.plot(mx,my,'+',c='r')

# %%
def FindLeadingEdge(e):
    
    event= e.iloc[1:-1]
    grad = np.gradient(event.values)
    mx = np.argmax(grad)
    my = grad[mx]
    
    tmp = e[['EventID','trigger']].values.tolist() +[mx,my]
    return pd.Series(tmp,index=['EventID','trigger','pos','height'])

    
tmp_df = pd.merge(convol_df,status_df,on='EventID')
tmp_df = tmp_df[~tmp_df['trigger'].isnull()]
tmp_df = tmp_df[tmp_df['trigger']<425]
peakdf = tmp_df.apply(FindLeadingEdge,axis=1)
#peakdf['pos'].hist(bins=200)
(peakdf['pos']-peakdf['trigger']+400).hist(bins=200)
plt.xlim([200,260])
plt.figure()
peakdf['pos'].hist(bins=200)
plt.xlim([180,250])
# Out:
# (180, 250)

# %%
def Shift(r):
    r1 = r.copy()
    r1.iloc[1:-1] = r1.iloc[1:-1].shift(int(380-r1['trigger']))
    return  r1.fillna(0)
tmp_df = pd.merge(convol_df,status_df,on='EventID')
tmp_df = tmp_df[~(tmp_df['trigger'].isnull())]
shift_df = tmp_df.apply(Shift,axis=1)
shift_df.iloc[1:-1].T.plot(c=(1,0,0,0.01),legend=None)

# %%
# %matplotlib notebook
heights = shift_df.iloc[:,1:-1].max(axis=1)
pos = shift_df.apply(FindLeadingEdge,axis=1)

#mask = (pos['pos']>205)&(pos['pos']<230)&(heights>42000)&(heights<53000)
mask = (pos['pos']>180)&(pos['pos']<220)&(heights>53000)&(heights<65000)

#heights[mask].hist()
#plt.figure()
print pos['pos'][mask].shape
plt.hist2d(pos['pos'].values,heights.values,bins=500,norm=LogNorm());
#plt.hist2d(pos['pos'][mask].values,heights[mask].values,bins=[np.linspace(200,230,15),np.linspace(44000,52000,20)],norm=LogNorm());
#plt.xlim([150,250]);
#plt.ylim([40000,80000]);
# Out:
# (457,)
# <img src="data:image/png;base64,..." width="432">

# %%
457/368.0
# Out:
# 1.2418478260869565

# %%
# %matplotlib inline
tmp_df = pd.merge(convol_df,status_df,on='EventID')
tmp_df = tmp_df[~tmp_df['trigger'].isnull()]
tmp_df = tmp_df[(tmp_df['trigger']<425)&(tmp_df['trigger']>330)]
peak1_df = tmp_df.apply(FindLeadingEdge,axis=1)
ids = peak1_df[((peak1_df['pos']-peak1_df['trigger']+400)>200)&((peak1_df['pos']-peak1_df['trigger']+400)<255)]['EventID']
tmp = shift_df.ix[ids]
heights = tmp.iloc[:,1:-1].max(axis=1)
heights.hist(bins=100)
plt.figure()
plt.plot(tmp[heights>52500].iloc[:,1:-1].T.values,c=(0,0,1,0.01));
plt.plot(tmp[heights<52500].iloc[:,1:-1].T.values,c=(1,0,0,0.01));
plt.xlim([150,400])
plt.ylim([0,70000])
plt.figure()
plt.plot(tmp[heights<52500].iloc[:,1:-1].T.values,c=(1,0,0,0.01));
plt.xlim([150,400])
plt.ylim([0,70000])
plt.figure()

# %%
mask = (pos['pos']>180)&(pos['pos']<220)&(heights>53000)&(heights<65000)
shift_df[mask].iloc[:,1:-1].T.plot(c=(1,0,0,0.01),legend=None)
plt.xlim([150,400])
DE0a = shift_df[mask].iloc[:,1:-1].iloc[:,350:400].sum(axis=1)
DE1a = shift_df[mask].iloc[:,1:-1].iloc[:,300:350].sum(axis=1)
DE2a = shift_df[mask].iloc[:,1:-1].iloc[:,250:300].sum(axis=1)
plt.figure()
plt.hist2d(DE0.values,DE1.values,bins=50);
plt.figure()
plt.scatter(DE0.values,DE1.values);
plt.figure()
mask1 = (pos['pos']>205)&(pos['pos']<240)&(heights<53000)&(heights>42000)
shift_df[mask1].iloc[:,1:-1].T.plot(c=(1,0,0,0.01),legend=None)
plt.xlim([150,400])
DE0b = shift_df[mask1].iloc[:,1:-1].iloc[:,350:400].sum(axis=1)
DE1b = shift_df[mask1].iloc[:,1:-1].iloc[:,300:350].sum(axis=1)
DE2b = shift_df[mask1].iloc[:,1:-1].iloc[:,250:300].sum(axis=1)
plt.figure()
plt.hist2d(DE0.values,DE1.values,bins=50);
plt.figure()
plt.scatter(DE0a.values,DE1a.values,c=(1,0,0,0.1));
plt.scatter(DE0b.values,DE1b.values,c=(0,1,0,0.1));
plt.figure()shi
plt.scatter(DE1a.values,DE2a.values,c=(1,0,0,0.1));
plt.scatter(DE1b.values,DE2b.values,c=(0,1,0,0.1));

# %%
tmp2 = tmp[heights<52500]
peak2_df = tmp2.apply(FindLeadingEdge,axis=1)
peak2_df['pos'].hist(bins=np.linspace(180,230,50))
plt.figure()
plt.plot(tmp2.ix[peak2_df[peak2_df['pos']<210]['EventID']].T.values,c=(1,0,0,0.01))
#plt.xlim([150,400])
#plt.figure()
plt.plot(tmp2.ix[peak2_df[peak2_df['pos']>=210]['EventID']].T.values,c=(0,0,1,0.01))
plt.xlim([150,400])
# Out:
# (150, 400)

# %%
heights = tmp.iloc[:,1:-1].max(axis=1)
heights.hist(bins=100)
#tmp[heights<52500].iloc[:,1:-1]
#tmp[heights<52500].iloc[:,1:-1].T.plot(legend=None)
plt.figure()
plt.plot(tmp[heights>52500].iloc[:,1:-1].T.values,c=(0,0,1,0.01));
plt.plot(tmp[heights<52500].iloc[:,1:-1].T.values,c=(1,0,0,0.01));
plt.xlim([150,400])
plt.ylim([0,70000])
plt.figure()
plt.plot(tmp[heights<52500].iloc[:,1:-1].T.values,c=(1,0,0,0.01));
plt.xlim([150,400])
plt.ylim([0,70000])
plt.figure()
plt.plot(tmp[heights>52500].iloc[:,1:-1].T.values,c=(0,0,1,0.01));
plt.xlim([150,400])
plt.ylim([0,70000])

sum((heights>52500)&(heights<70000)),sum((heights<52500)&(heights>40000))
# Out:
# (493, 396)

# %%
grad = np.gradient(tmp[heights<52500].iloc[:,1:-1],axis=1)
plt.plot(grad[:,10:-10].T,c=(1,0,0,0.01));
plt.xlim([150,250])
plt.figure()
plt.hist(np.argmax(grad,axis=1)+10,bins=100);
plt.xlim([200,300])
grad = np.gradient(tmp.iloc[:,1:-1],axis=1)

plt.figure()
plt.hist(np.argmax(grad,axis=1)+10,bins=100);
plt.xlim([200,300])
# Out:
# (200, 300)
